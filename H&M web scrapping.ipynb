# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
#Any page url that you are interested in H and M website

URL = 'https://www2.hm.com/en_us/women/new-arrivals/view-all.html'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

#Links of each product in the above given web page
links = soup2.find_all("a",attrs={'class':'item-link'})

# %%
#Get title of a product in the given web page
def get_title(soup):

    try:
        title = soup.find("h1").get_text().strip()
    
    except AttributeError:
        title = ""

    return title

#Get price of a product in the given web page
def get_price(soup):

    try:
        price = soup.find("span",attrs={"class":'price-value'}).get_text().strip()
    
    except AttributeError:
        price = ""

    return price

# %%
#Initializing a variable that stores the title and price of all products in the given page
d = {"title":[], "price":[]}
for link in links:
    #Getting new webpage for each product
    new_webpage = requests.get("https://www2.hm.com" + link.get('href'), headers=headers)

    new_soup = BeautifulSoup(new_webpage.content, "html.parser")

    # Function calls to display all necessary product information
    d['title'].append(get_title(new_soup))
    d['price'].append(get_price(new_soup))

# %%
import pandas as pd
import numpy as np

handm_df = pd.DataFrame.from_dict(d)
handm_df['title'].replace('', np.nan, inplace=True)
handm_df = handm_df.dropna(subset=['title'])
handm_df.to_csv("HandM.csv", header=True, index=False)

# %%
handm_df
# Out:
#                                   title   price
# 0          Linen-blend Wrap-front Skirt  $34.99
# 1      Oversized Off-the-shoulder Dress  $49.99
# 2               Ribbed One-shoulder Top  $12.99
# 3                Oversized Resort Shirt  $17.99
# 4                    Crochet-look Skirt  $49.99
# 5                Wide-cut Pull-on Pants  $32.99
# 6             Asymmetric-hem Slip Dress  $64.99
# 7                Crêped High-slit Skirt  $24.99
# 8                     Crêped Slip Dress  $24.99
# 9                    Twist-detail Dress  $17.99
# 10              Cotton Halterneck Dress  $24.99
# 11                        Crêped Shorts  $12.99
# 12                 V-neck Bodycon Dress  $34.99
# 13           Ladder-stitch-look Sweater  $24.99
# 14               Rib-knit Bodycon Dress  $39.99
# 15                        Fine-knit Top  $17.99
# 16  Twist-detail Rib-knit Bandeau Dress  $34.99
# 17  Twist-detail Rib-knit Bandeau Dress  $34.99
# 18                         Denim Shorts  $29.99
# 19           Open-backed Rib-knit Dress  $34.99
# 20               Rib-knit Bodycon Dress  $39.99
# 21           Ladder-stitch-look Sweater  $24.99
# 22                      Ribbed Tank Top  $12.99
# 23                  A-line Jersey Dress  $12.99
# 24                      Oval Sunglasses  $13.99
# 25                   Puff-sleeved Dress  $29.99
# 26                  Triangle Bikini Top  $12.99
# 27             Brazilian Bikini Bottoms  $12.99
# 28         Ruffle-trimmed Chiffon Dress  $39.99
# 29       High Leg One-shoulder Swimsuit  $24.99
# 30             A-line Dress with Lacing  $39.99
# 31                2-pack Bikini Bottoms  $17.99
# 32           Smocked Bandeau Bikini Top  $14.99
# 33           5-pack Cotton Thong Briefs  $14.99
# 34                           Bikini Top  $12.99
# 35               2-pack Ribbed Bra Tops  $17.99
